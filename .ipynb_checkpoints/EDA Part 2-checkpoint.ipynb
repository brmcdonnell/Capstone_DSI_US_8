# %% [markdown]
# # EDA Part II

# %% [markdown]
# <i>**Author:** Brendan McDonnell</i>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('manual_date_imputation.csv')

# %% [markdown]
# ## Dealing With the Date Column

# %%
# taken from stack overflow: https://stackoverflow.com/questions/3418050/month-name-to-month-number-and-vice-versa-in-python
def month_to_num(short_month):

    return {
        'jan' : 1,
        'feb' : 2,
        'mar' : 3,
        'apr' : 4,
        'may' : 5,
        'jun' : 6,
        'jul' : 7,
        'aug' : 8,
        'sep' : 9, 
        'oct' : 10,
        'nov' : 11,
        'dec' : 12
    }[short_month]

# %%
def date_to_season(date):
    if ',' in date:
        date = date.split(',')
        year = int(date[1])
        if '/' in date[0]:
            month = int(date[0].split('/')[0])
            day = int(date[0].split('/')[1].split()[0])
        elif '-' in date[0]:
            month = date[0].split()[0]
            day = int(date[0].split()[1].split('-')[0])
    else:
        date = date.split('-')
        year = int('20' + date[2])
        month = month_to_num(date[1].lower())
        day = int(date[0])
    return str(year) + '-' + str(month) + '-' + str(day)

# %%
df['datetime'] = pd.to_datetime(df.Date.map(date_to_season))

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#                  Name   Grade            Team              Location  \
# 0  Abbie Hetherington  (Sr-4)  Oklahoma State  Big 12 Championships
# 1  Abbie Hetherington  (Sr-4)  Oklahoma State  Big 12 Championships
# 2  Abbie Hetherington  (Sr-4)  Oklahoma State    Arkansas Qualifier
# 3  Abbie Hetherington  (Sr-4)  Oklahoma State    2019 Husky Classic
# 4  Abbie Hetherington  (Sr-4)  Oklahoma State  2019 UW Invitational
#
#                     Date Events Performance     Place event  is_relay  \
# 0   02/22 - Feb 23, 2019   1000     02:59.0   8th (F)  1000         0
# 1   02/22 - Feb 23, 2019   1000     02:51.0   4th (P)  1000         0
# 2              15-Feb-19    800     02:11.7   3rd (F)   800         0
# 3  02/08 - Feb  09, 2019    800     02:11.1  15th (F)   800         0
# 4   01/25 - Jan 26, 2019    800     02:10.0  18th (F)   800         0
#
#    has_hurdles  is_field_event  is_multi_event   datetime
# 0            0               0               0 2019-02-22
# 1            0               0               0 2019-02-22
# 2            0               0               0 2019-02-15
# 3            0               0               0 2019-02-08
# 4            0               0               0 2019-01-25

# %%
# DNF; can get rid of the one performance that is null (source: https://www.tfrrs.org/athletes/5464384.html

df.dropna(axis=0, subset=['Performance'], inplace=True)

# %% [markdown]
# ##  Updating Time Column for Purdy Points Eligible Events

# %% [markdown]
# ### Taking Care of Performances and Places

# %%
# all the non time or numeric values that exist in the performance category need to be removed; here's the list
list_of_non_performances = list(df[~df.Performance.str.contains('\d')].Performance.unique())

# %%
df = df[~df['Performance'].isin(list_of_non_performances)]

# %%
# fill NA's in the place column w/ 999
df.Place = df.Place.fillna('999')

# %%
df.shape
# Out:
# (187176, 14)

# %%
# quick check
df[~df.Place.str.contains('p|P|f|F|999')].Place.unique()
# Out:
# array(['26th', '57th', '40th', '178th', '36th', '23rd', '63rd', '111st',
#        '49th', '218th', '12th', '21st', '27th', '24th', '116th', '25th',
#        '52nd', '9th', '226th', '34th', '35th', '68th', '59th', '78th',
#        '16th', '45th', '3rd', '2nd', '17th', '1st', '120th', '15th',
#        '31st', '38th', '10th', '6th', '79th', '163rd', '8th', '70th',
#        '219th', '13th', '91st', '46th', '126th', '129th', '5th', '19th',
#        '100th', '60th', '237th', '167th', '18th', '144th', '7th', '65th',
#        '190th', '14th', '67th', '74th', '200th', '90th', '29th', '172nd',
#        '115th', '75th', '11th', '56th', '131st', '101st', '66th', '28th',
#        '4th', '146th', '183rd', '157th', '55th', '72nd', '136th', '133rd',
#        '207th', '54th', '73rd', '182nd', '122nd', '58th', '170th', '22nd',
#        '53rd', '95th', '102nd', '124th', '64th', '105th', '245th',
#        '171st', '37th', '48th', '165th', '41st', '33rd', '162nd', '61st',
#        '30th', '32nd', '140th', '77th', '224th', '76th', '147th', '137th',
#        '47th', '113rd', '50th', '125th', '189th', '261st', '205th',
#        '216th', '87th', '83rd', '217th', '42nd', '51st', '160th', '89th',
#        '43rd', '99th', '259th', '44th', '20th', '173rd', '235th', '232nd',
#        '143rd', '62nd', '84th', '196th', '98th', '145th', '85th', '210th',
#        '271st', '148th', '135th', '193rd', '92nd', '118th', '150th',
#        '214th', '198th', '109th', '39th', '206th', '188th', '179th',
#        '103rd', '123rd', '82nd', '141st', '149th', '227th', '166th',
#        '96th', '80th', '81st', '88th', '161st', '174th', '117th', '86th',
#        '127th', '158th', '128th', '106th', '155th', '181st', '191st',
#        '251st', '203rd', '213rd', '246th', '132nd', '195th', '228th',
#        '119th', '252nd', '110th', '248th', '208th', '69th', '177th',
#        '151st', '138th', '130th', '222nd', '234th', '239th', '114th',
#        '139th', '379th', '153rd', '164th', '108th', '71st', '142nd',
#        '215th', '180th', '176th', '175th', '93rd', '223rd', '107th',
#        '229th', '262nd', '236th', '94th', '104th', '185th', '233rd',
#        '154th', '186th', '156th', '168th', '220th', '194th', '202nd',
#        '257th', '242nd', '187th', '134th', '152nd', '211st', '267th',
#        '241st', '197th', '192nd', '97th', '284th', '112nd', '260th',
#        '263rd', '240th', '121st', '201st', '230th', '225th', '305th',
#        '255th', '204th', '307th', '159th', '324th', '256th', '231st',
#        '286th', '279th', '247th', '266th', '209th', '334th', '244th',
#        '258th', '312nd', '212nd', '221st', '326th', '169th', '243rd',
#        '238th', '289th', '270th', '272nd', '199th', '274th', '308th',
#        '327th', '280th', '302nd', '268th', '277th', '184th', '338th',
#        '329th', '253rd', '309th', '276th', '265th', '285th', '249th',
#        '287th', '318th', '292nd', '323rd', '254th', '264th', '303rd',
#        '391st', '278th', '333rd', '250th', '356th', '282nd', '290th',
#        '288th', '273rd', '331st', '330th', '311st', '281st', '341st',
#        '283rd', '298th', '351st', '299th', '382nd', '291st', '320th'],
#       dtype=object)

# %%
# mark prelims values for place
df['is_prelim'] = df.Place.str.contains('p|P')

# %%
def return_place(place):
    strip_string = '() abcdefghijklmnopqrstuvwxyz'
    if place == '999':
        return int(place)
    else:
        place = place.lower().strip(strip_string)
        if place == '':
            return 999
        else:
            return int(place)

# %%
df['Place'] = df.Place.apply(return_place)

# %%
# Create columns indicating season type for each season in dataset

# 2010-11 Indoor Track Season
df['indoor_season_2011'] = df.datetime <= '2011-03-01'

# 2011 Outdoor Track Season
df['outdoor_season_2011'] = (('2011-03-01' <= df.datetime) &
                            (df.datetime <= '2011-07-31'))

# 2011 XC Season Has 0 Entries

# 2011-12 Indoor Track Season
df['indoor_season_2012'] = (('2011-12-01' <= df.datetime) & 
                            (df.datetime <= '2012-03-02'))

# 2012 Outdoor Track Season
df['outdoor_season_2012'] = (('2012-03-03' <= df.datetime) & 
                             (df.datetime <= '2012-07-31'))

# 2012 XC Season Has 0 Entries

# 2012-13 Indoor Track Season
df['indoor_season_2013'] = (('2012-11-20' <= df.datetime) & 
                            (df.datetime <= '2013-03-10'))

# 2013 Outdoor Track Season
df['outdoor_season_2013'] = (('2013-03-10' <= df.datetime) & 
                             (df.datetime <= '2013-07-31'))

# 2013 XC Season
df['xc_season_2013'] = (('2013-08-01' <= df.datetime) & 
                        (df.datetime <= '2013-11-30'))

# 2013-14 Indoor Track Season
df['indoor_season_2014'] = (('2013-12-01' <= df.datetime) & 
                            (df.datetime <= '2014-03-15'))

# 2014 Outdoor Track Season
df['outdoor_season_2014'] = (('2014-03-16' <= df.datetime) & 
                             (df.datetime <= '2014-07-31'))

# 2014 XC Season
df['xc_season_2014'] = (('2014-08-01' <= df.datetime) & 
                        (df.datetime <= '2014-11-30'))

# 2014-15 Indoor Track Season
df['indoor_season_2015'] = (('2014-12-01' <= df.datetime) & 
                           (df.datetime <= '2015-03-13') & 
                           (df.Location != '2015 Ben Brown Invitational') & 
                           (df.Location != 'Cal State LA Invitational') & 
                           (df.Location != 'Cal Opener 2015') & 
                           (df.Location != '2015 Skyline HS / Joel Ezar Track Classic') & 
                           (df.Location != 'Jaguar Opener'))

# 2015 Outdoor Track Season
df['outdoor_season_2015'] = (('2015-03-06' <= df.datetime) & 
                             (df.datetime <= '2015-07-31') &
                             (df.Location != 'NCAA Division I Indoor Track & Field Championships') &
                             (df.Location != '2015 IC4A/ECAC Indoor Track & Field Championships'))

# 2015 XC Season
df['xc_season_2015'] = (('2015-08-01' <= df.datetime) &
                        (df.datetime <= '2015-11-21'))

# 2015-16 Indoor Track Season
df['indoor_season_2016'] = (('2015-11-22' <= df.datetime) &
                            (df.datetime <= '2016-03-11'))

# 2016 Outdoor Track Season
df['outdoor_season_2016'] = (('2016-03-12' <= df.datetime) &
                             (df.datetime <= '2016-08-21'))

# 2016 XC Season
df['xc_season_2016'] = (('2016-08-22' <= df.datetime) &
                        (df.datetime <= '2016-11-19'))

# 2016-17 Indoor Track Season
df['indoor_season_2017'] = (('2016-11-20' <= df.datetime) &
                            (df.datetime <= '2017-03-10') &
                            (df.Location != 'Central Arkansas Spring Opener'))

# 2017 Outdoor Track Season
df['outdoor_season_2017'] = (('2017-03-10' <= df.datetime) &
                             (df.datetime < '2017-08-04') &
                             (df.Location != 'NCAA Division I Indoor Track & Field Championships'))

# 2017 XC Season
df['xc_season_2017'] = (('2017-08-05' <= df.datetime) & 
                        (df.datetime <= '2017-11-20'))

# 2017-18 Indoor Track Season
df['indoor_season_2018'] = (('2017-11-21' <= df.datetime) &
                            (df.datetime <= '2018-03-09'))

# 2018 Outdoor Track Season
df['outdoor_season_2018'] = (('2018-03-10' <= df.datetime) &
                             (df.datetime < '2018-7-31'))

# 2018 XC Season
df['xc_season_2018'] = (('2018-08-01' < df.datetime) & 
                        (df.datetime < '2018-11-20'))

# 2018-19 Indoor Track Season
df['indoor_season_2019'] = (('2018-11-21' <= df.datetime) & 
                            (df.datetime <= '2019-03-12'))

# 2019 Outdoor Track Season
df['outdoor_season_2019'] = ('2019-03-13' <= df.datetime)

# %% [markdown]
# ### Indicating Championships; Conference, Regional, and National

# %%
list(df.Location.unique())
# Out:
# ['Big 12 Championships',
#  'Arkansas Qualifier',
#  '2019 Husky Classic',
#  '2019 UW Invitational',
#  'Arkansas Invitational',
#  'Big 12 Cross Country Championships',
#  'Arturo Barrios Invitational',
#  'Nuttycombe Wisconsin Invitational Presented By Under Armour',
#  'NCAA West Preliminary Round',
#  'Arkansas Twilight',
#  'National Relay Championships',
#  'John McDonnell Invitational',
#  'Stanford Invitational',
#  'NCAA Division I Indoor Track & Field Championships',
#  'Big 12 Indoor Track & Field Championships',
#  '2018 Husky Classic',
#  'Razorback Invitational',
#  'NCAA Division I West Preliminary Round',
#  'Big 12 Outdoor Track & Field Championships',
#  '2017 Drake Relays presented by Hy-Vee',
#  'Arkansas Spring Invitational',
#  '2017 Husky Classic',
#  '2017 Holiday Inn Invitational',
#  'NCAA Division I Cross Country Championships',
#  'NCAA Division I Midwest Region Cross Country Championships',
#  '2016 Big 12 Cross Country Championships',
#  'Penn State National Open',
#  'Iowa State Classic',
#  'Rock Chalk Classic',
#  'Jim Click Shootout',
#  'NCAA DI Cross Country Championships',
#  'Alabama Crimson Classic Cross Country Invitational',
#  'Cowboy Jamboree',
#  'Big 12 Conference Outdoor Track and Field Championships',
#  '2018 Cardinal Classic',
#  '2015 UW Husky Classic',
#  'KSU Deloss Dodds Triple Dual',
#  '2014 Big 12 Cross Country Championship',
#  'Kentucky Bluegrass Cross Country Invitational',
#  '2018 Alex Wilson Invitational',
#  'Corky Classic',
#  '2017 Big 12 Cross Country Championship',
#  "OSU Cowboy Jamboree Women's 6K (Orange)",
#  'NCAA Division I Outdoor Track & Field Championships',
#  'Bryan Clay Invite',
#  'OSU Cowboy Jamboree',
#  'Penn Relays',
#  'Bryan Clay Invitational',
#  'University of Tulsa Duels',
#  'Texas A&M Team Invitational',
#  '2015 Drake Relays presented by Hy-Vee',
#  'Mt. SAC Relays',
#  '2015 Clyde Littlefield Texas Relays',
#  'Holiday Inn Invite',
#  'Bronco Invitational (Invite Section)',
#  'Michael Johnson Invitational',
#  'Michigan Power 5 Invitational',
#  'Texas A&M Quadrangular',
#  'Boston University Season Opener',
#  'NCAA Division I South Central Region Cross Country Championships',
#  'Joe Piane Notre Dame Invitational',
#  'SMU vs Baylor (Women)',
#  'TCU vs Baylor',
#  'Roadrunner Invitational',
#  'Charlie Thomas Invitational',
#  '2017 Rod McCravy Memorial T&F Meet',
#  'Joe Piane Invitational',
#  'Texas A&M Invitational',
#  'Baylor vs SMU (Women)',
#  'Big 12 Outdoor Track and Field Championships',
#  'Baylor Invitational',
#  'USC Trojan Invite',
#  'NCAA Division I West Region Preliminary Rounds',
#  'The Reveille Meet',
#  '2018 TCU Invitational',
#  'Tyson Invitational',
#  '2019 92nd Clyde Littlefield Texas Relays',
#  'Texas Tech Classic',
#  'Larry Wieczorek Invitational',
#  'Ted Nelson Invitational Saturday',
#  '2018 Joe Piane - Notre Dame Invitational',
#  'UTA Gerald Richey Invitational',
#  'Bear Twilight',
#  'NCAA Division I Outdoor Championships',
#  'Home Depot Clyde Littlefield Texas Relays',
#  'Texas Tech Matador Qualifier',
#  'USATF U20 Championships',
#  'Texas Tech Red Raider Shoot-Out',
#  'Texas Tech Matador Quaifier',
#  'adidas DI Pre Nationals',
#  'North Texas Ken Garland Invitational',
#  'Texas Invitational',
#  'North Texas vs Baylor (Men)',
#  'Aggieland Open',
#  '2017 90th Clyde Littlefield Texas Relays',
#  '2017 TCU Invitational',
#  'North Texas Ken Garland Inivitational',
#  'Baylor vs North Texas (Men)',
#  'Baylor vs. TCU (Men)',
#  'Chile Pepper Festival',
#  'Gerald Richey Cross Country Invitational',
#  'Ken Garland Invitational',
#  'USATF Junior Championships',
#  'Michael Johnson Classic',
#  '2016 Drake Relays presented by Hy-Vee',
#  '2016 Baylor Invitational',
#  'Ricardo Romo Invitational',
#  'TCU Invitational',
#  '2016 Rod McCravy Memorial Track & Field Meet',
#  'IAAF World Championships',
#  '2018 Pac-12 Track & Field Championships',
#  '2018 Ken Shannon Invitational',
#  'WSU-UW Dual',
#  'Oregon Pepsi Invitational',
#  '2016 Nike Clyde Littlefield Texas Relays',
#  'USC Trojan Invitational',
#  'MPSF Indoor Track & Field Championships',
#  'Don Kirby Elite',
#  '2018 UW Invitational',
#  '2018 UW Preview',
#  'Pac-12 Championships',
#  '2017 Ken Shannon Invitational',
#  '2017 UW v. WSU Dual',
#  'Beach Invitational',
#  '2015 Wisconsin adidas Invitational',
#  'Trojan Invitational',
#  'Bear Twilight Invitational',
#  'Longhorn Invitational',
#  'IAAF World U20 Championships',
#  '2017 UW Invitational',
#  '2016 U.S. Olympic Trials',
#  '2017 UW Indoor Preview',
#  'NCAA Division I Track & Field Championships',
#  'Pac-12 Outdoor Track & Field Championships',
#  'Ken Shannon Invitational',
#  'Wisconsin Pre Nationals',
#  'WSU-UW Dual Meet',
#  'Pepsi Invitational',
#  'Pac-12 vs Big 10 Invitational',
#  'Texas A&M Aggie Invitational',
#  'UW Open',
#  'Husky Classic',
#  'UW Invitational',
#  '2016 UW Indoor Preview',
#  'John Jacobs Invitational',
#  'Rafer Johnson & Jackie Joyner-Kersee Invitational',
#  '2019 TCU Invitational',
#  'Dr. Sander Columbia Challenge',
#  'Sooner Challenge',
#  'Crimson Classic',
#  "OSU Cowboy Jamboree Men's 8K (Orange)",
#  'Cowboy Preview - Oklahoma State vs Oklahoma (Men)',
#  'Cowboy Preview - Oklahoma vs Arkansas (Men)',
#  'Cowboy Preview - Oklahoma vs Tulsa (Men)',
#  '2017 Alex Wilson Invitational',
#  'Crimson Tide Invitational',
#  '40th Annual Aztec Invitational',
#  'Rafer/JJK Invitational',
#  'Vanderbilt Invitational',
#  'J.D. Martin Invitational',
#  'Sooner Opener',
#  'ISU adidas Pre Nationals',
#  'ROY GRIAK INVITATIONAL',
#  'Oklahoma John Jacobs Invitational',
#  'LSU Battle on the Bayou',
#  'UT Arlington Bobby Lane Invitational',
#  'Bobby Lane Invitational',
#  'Baldy Castillo Invitational',
#  '2017 Armory Track Invitational (Colleges)',
#  'Alex Wilson Invitational 2016',
#  '2017 Mark Colligan Memorial',
#  'TCU College Invite',
#  'Arkansas Open',
#  '2015 Rod McCravy Memorial Track & Field Meet',
#  'Alex Wilson Invitational',
#  'K-State Winter Invitational',
#  'Texas Tech Corky/Crofoot Shootout',
#  'Kansas Relays',
#  '2018 Jim Click Shootout',
#  'Emporia State Relays',
#  'Ward Haylett Invitational',
#  '2019 KSU Steve Miller Open',
#  '40th Sun Angel Track Classic',
#  '41st Annual Aztec Invitational',
#  '41st Annual Aztec Open',
#  'Texas Tech Shootout',
#  '2019 KU KSU WSU Triangular',
#  'Carol Robinson/Attila Zsivoczky Pentathlon',
#  'DeLoss Dodds Invitational',
#  'KSU-KU-WSU Triangular',
#  'Kansas State Wildcat Invitational',
#  'UW-Parkside Vic Godfrey Open',
#  'Wichita State JK Gold Classic - College/University',
#  'Wichita State JK Gold Classic Non-Division 1 Meet',
#  '2019 Frank Sevigne Husker Invitational',
#  'Kansas State Ward Haylett Invite',
#  '2018 Nebraska Tune-Up',
#  'Texas State Bobcat Invitational',
#  'Bob Timmons Challenge',
#  'Bradley Pink Classic',
#  'Rim Rock Classic',
#  'Wichita State KT Woodman Classic',
#  'KSU Ward Haylett Invite',
#  '2017 Kip Janvrin Open',
#  'KSU Steve Miller Open',
#  '42nd Annual Frank Sevigne Husker Invitational',
#  'New Mexico Team Invitational',
#  'Kansas State DeLoss Dodds Invitational',
#  '2018 Drake Relays presented by Hy-Vee',
#  'Kansas State Winter Invitational',
#  '2016 Ward Haylett Invitational',
#  'Drake Relays presented by Hy-Vee',
#  '2016 KU-KSU-WSU Triangular',
#  'Kansas State Wildcat Invite',
#  'KSU Winter Invitatonal',
#  'Woody Greeno/Jay Dirksen University Division',
#  'JK Gold Classic - Kansas State vs. Missouri State',
#  'JK Gold Classic - Wichita State vs. Kansas State',
#  'JK Gold Classic- Missouri vs. Kansas State',
#  'Wichita State vs Kansas vs Kansas State',
#  '2017 Bill Easton Classic',
#  '3rd Annual Indoor Gorilla Classic',
#  'Hawkeye Invitational',
#  '39th Sun Angel Classic',
#  "Parent's Day Invitational",
#  'Cyclone Duals',
#  'Musco Twilight',
#  'Tulsa Duels',
#  'War Eagle Invitational 2019',
#  'Jimmy Grant Invitational',
#  '2018 Nebraska Invitational',
#  'Florida Relays',
#  '2018 Frank Sevigne Husker Invite',
#  'Cardinal Classic',
#  'Hawkeye Invitational - Creighton vs Iowa State',
#  'Hawkeye Invitational - Drake vs Iowa State',
#  'Hawkeye Invitational - Illinois State vs Iowa State',
#  'Hawkeye Invitational - Iowa Central CC vs Iowa State',
#  'Hawkeye Invitational - Iowa State vs Northern Iowa',
#  'Hawkeye Invitational - Iowa vs Iowa State',
#  'Stanford Cardinal Classic',
#  'Nuttycombe Wisconsin Invitational B Race',
#  'Hawkeye Invitational - Bradley vs Iowa State',
#  'Hawkeye Invitational - Illinois vs Iowa State',
#  'Hawkeye Invitational - Iowa State vs Missouri',
#  'Virginia Challenge',
#  '2016 Jim Duncan Invitational',
#  'San Francisco State Distance Carnival',
#  'Big 4 Duals',
#  '2016 Holiday Inn Invitational',
#  'Greater Louisville Classic',
#  'Oz Memorial',
#  'Hawkeye Early Bird Invitational',
#  'Black & Gold Premier',
#  'Penn State National',
#  'The 12th Annual Sand Shark Invitational',
#  'UAB Blazer Classic',
#  '2018 Mountain Dew Gator Cross Country Invitational',
#  'Falcon Classic',
#  'NCAA Division I South Region Cross Country Championships',
#  'MEAC Cross Country Championships',
#  '2017 Bulldog Duels',
#  'FSU Invitational',
#  'Florida A&M vs Jackson State (Men)',
#  'Ole Miss vs Florida A&M',
#  '38th Sun Angel Classic',
#  'Payton Jordan Invitational',
#  'JDL DMR Invitational',
#  'Iowa Big 4 Duals',
#  'Camel City Invitational',
#  'Boston Univ. Bruce Lehane Scarlet and White Invitational',
#  '2017 Nebraska Invitational',
#  'Rim Rock Collegiate Classic',
#  'Boston University Bruce Lehane Scarlet and White Invitationa',
#  'California Collegiate Open',
#  'Shell Shocker Meet',
#  'NCAA Division I Great Lakes Region Cross Country Championships',
#  'Big Ten Cross Country Championships',
#  'Louisville Classic',
#  'Nittany Lion Challenge',
#  'Musco Invitational',
#  'LSU Alumni Gold',
#  '2015 Jim Duncan Invitational',
#  'Tiger Track Classic 2015',
#  'UNI Dome Open',
#  'NCAA Division I Southeast Region Cross Country Championships',
#  'ACC Championships',
#  'Raleigh Relays',
#  'ACC Indoor Track & Field Championships',
#  'Music City Challenge',
#  'Clemson Bob Pollock Invitational',
#  '2018 Navy Winter Invitational Track & Field Meet',
#  'ACC Cross Country Championships',
#  'Paul Short Gold',
#  'Emporia State Spring Invite',
#  '2017 Jayhawk Classic',
#  '2016 ESU Relays',
#  '2016 Bill Easton Classic',
#  'Texas Tech Open',
#  '2019 Oral Roberts Invitational',
#  'Mike Fanelli Track Classic',
#  '37th Annual Sun Angel Classic',
#  '2019 Jayhawk Classic',
#  'Power Five Invitational',
#  '2018 Rod McCravy Memorial Track & Field Meet',
#  '2018 Jayhawk Classic',
#  '2018 Mark Colligan Memorial',
#  "2018 Jimmy John's ORU Invite",
#  'Penn State Relays',
#  '2017 Emporia State Relays',
#  '2016 Bob Timmons Challenge',
#  'Wisconsin adidas Invitational',
#  'Roy Griak Invitational',
#  '2017 Bob Timmons Challenge',
#  'Bob Timmons Invitational',
#  'Star Athletics Sprint Series #2',
#  'Martin Luther King, Jr Invitational',
#  '2016 Jayhawk Classic',
#  '2015 Bob Timmons Challenge',
#  '2015 Jayhawk Classic',
#  '2015 Bill Easton Classic',
#  '2014 Bob Timmons',
#  '2014 Mesa Classic',
#  '35th Sun Angel Track Classic',
#  'Kansas  Relays',
#  'DI Pre-Nationals',
#  '2014 ESU Spring Open',
#  '2014 Armory Collegiate Invitational',
#  '2014 Jayhawk Classic',
#  '2014 Bill Easton Classic',
#  '40th Annual Frank Sevigne Husker Invitational',
#  'Southland Conference Outdoor Track and Field Championship',
#  'Texas A&M Alumni Muster',
#  '41st Annual Frank Sevigne Husker Invitational',
#  'Ward Haylett Inv',
#  '2013 Kansas Relays',
#  'Leon Johnson NSU Invitational',
#  'Louisiana Classics',
#  '2013 Mesa Classic',
#  '34th Sun Angel Classic',
#  'ISU Pre-National Invitational',
#  'USATF Championships',
#  '2013 Armory Collegiate Invitational',
#  '2013 Jayhawk Classic',
#  '2014 Clyde Littlefield Texas Relays',
#  'Bob Timmons Dual Classic',
#  '2013 Jayhawk Challenge',
#  '2013 Bill Easton Classic',
#  '2012 Bob Timmons Challenge',
#  'Rim Rock Farm Collegiate Classic',
#  'Bob Timmons Dual Classic KU vs Oral Roberts',
#  'Bob Timmons Dual Classic KU vs UMKC',
#  '2016 Mesa Classic',
#  '2019 Triton Invitational',
#  'UTSA Invitational',
#  '2018 Kip Janvrin Open',
#  'Miami Hurricane Collegiate Invitational',
#  'Bradley "Pink" Classic',
#  'Woody Greeno/Jay Dirksen Invitational',
#  'Augie Twilight',
#  "Bradley 'Pink' Classic Invitational",
#  '2015 Bob Timmons Dual Classic',
#  'MAC championship',
#  'John McNichols Invitational',
#  'Mel Brodt Collegiate Opener',
#  'Toledo Opener',
#  'Hillsdale "GINA" Relays - 52nd Edition',
#  'Ohio State Univ. - Jesse Owens Track Classic',
#  'Hillsdale Invitational',
#  'Michigan - Silverston Invitational',
#  'GVSU Big Meet- Friday',
#  '2017 Mid-American Conference XC Championships',
#  'MSU Spartan Invitational',
#  '2017 Jesse Owens University Classic',
#  'All Ohio Champs',
#  'Bruin Legends of T&F Invitational',
#  'Bruin Legends of T&F Distance Carnival',
#  'Oliver Nikoloff Invitational',
#  'Thundering Herd Invitational & Multi',
#  'Tom Wright Classic @BGSU',
#  'Mid-American Conference Cross Country Championships',
#  'Mel Brodt XC Invitational',
#  'Jesse Owens Track & Field Classic - Ohio State University',
#  'All-Ohio Championships',
#  'Oliver Nikoloff Invite Day 2 (Invited Teams)',
#  'Chipotle Marshall Invitational',
#  'Mel Brodt XC Invite',
#  '43rd Annual Norry Hersey Rice Invitational Cross Country Mee',
#  'Texas Invitational Cross Country Meet',
#  'New Mexico Classic',
#  'Clemson Invitational',
#  'Reveille Invitational',
#  'KSU Carol Robinson Pentathlon',
#  'Clemson Opener',
#  'Leonard Hilton Invitational',
#  'Victor Lopez Classic',
#  'UCO Alumni Classic',
#  'Panorama Farms Invitational',
#  '2018 Region VI Outdoor Track & Field Championships',
#  '2018 Cowley Tiger Invite',
#  'Bob Larsen Distance Carnival',
#  'Don Kirby Open & Elite',
#  'Big Ten Championships',
#  'UCSD Triton Invitational',
#  'Pac-12+ vs Big Ten Invitational',
#  'Air Force Invitational',
#  '2018 Graduate Classic',
#  'Aggie Opener',
#  'Conference Clash / Power 5 Invite',
#  'Texas A&M Aggie Twilight',
#  'Longhorn Invitational Cross Country Meet',
#  'Houston Invitational',
#  'Houston Invitational 2017',
#  'The American Outdoor Track & Field Championships',
#  'Texas State Bobcat Classic',
#  'Power Conference Cardinal & Gold',
#  'SFA Lumberjack SLC Preview',
#  'The American Indoor Track & Field Championships',
#  'Crimson & Gold Invitational',
#  'New Mexico Cherry & Silver',
#  '2015 Penn Relays',
#  'UTSA Texas Challenge Invitational',
#  'Virginia v. Maryland, Pitt, West Virginia',
#  '2019 Liberty Flames Invite',
#  'Meyo Invitational',
#  'Arkansas v. Texas',
#  'UTSA Ricardo Romo Classic',
#  'NCAA East Preliminary Round',
#  '2018 Conference USA Outdoor Track & Field Championships',
#  'ULM Warhawk Classic',
#  "The Skecher's Performance Carl Kight Invitational",
#  'Pittsburg State Invitational',
#  'Ted Nelson Invitational Friday',
#  'A-State Kickoff Klassic',
#  'Michael Johnson/Dr. Pepper Classic',
#  '2019 Alex Wilson Invitational',
#  'Arkansas v. Texas Dual Meet',
#  '2015 ESU Spring Open',
#  'Boston University / Sharon Colyear-Danville Season Opener',
#  'Holiday Inn Invitational',
#  'NCAA Division I National Championships',
#  'ESU Spring Open',
#  '2012 UCSD Triton Invitational (Colleges)',
#  '2012 Kansas Relays',
#  'UTEP Invitational',
#  'Baker Relays',
#  '2012 New Balance Collegiate Invitational',
#  '2012 Jayhawk Classic',
#  'Missouri vs Kansas Dual Meet',
#  '2012 Bill Easton Classic',
#  '2011 Bob Timmons Challenge',
#  'NCAA Division I Championships',
#  'ULM Warhawk Classic/NJCAA Super Southeast Regional',
#  '2011 Kansas Relays',
#  '2011 Clyde Littlefield Texas Relays',
#  '2011 Big 12 Indoor Track & Field Championships',
#  '2011 New Balance Collegiate Invitational',
#  'Kansas Jayhawk Classic',
#  '2011 KU-MU Dual',
#  '2011 Bill Easton Classic',
#  'Wichita State College Invitational',
#  'Wichita State Decathlon/Heptathlon',
#  'Mountain West Outdoor Track & Field Championship',
#  'Jack Christiansen Invitational',
#  'Pacific Coast Intercollegiate',
#  'Doug Max Invitational',
#  '2019 Tom Benich Invite',
#  'Fum McGraw',
#  'JK Gold Classic College/University',
#  'Nebraska Invitational',
#  'Brutus Hamilton Challenge',
#  'KSU Open',
#  '2014 Drake Relays presented by Hy-Vee',
#  'Cal State LA Twilight Open',
#  '2014 Jim Click Shootout',
#  'TCU College Invitational',
#  'Kansas State Univ Open',
#  'Bill Bergan Invitational',
#  'KSU Invitational',
#  'K-State Invitational',
#  'ESU Mid-Week Open',
#  'KT Woodman',
#  '2013 Jim Click Shootout',
#  '2013 ASU Invitational',
#  '2013 Baldy Castillo Invitational',
#  'New Mexico Don Kirby Open',
#  'New Mexico Don Kirby Elite',
#  'Wildcat Invite',
#  'KSU All-Comers',
#  'NACAC U23 Championships',
#  'Cowboy Preview - Oklahoma State vs Arkansas',
#  'Cowboy Preview - Oklahoma State vs Oklahoma',
#  'Cowboy Preview - Oklahoma State vs Tulsa',
#  '2017 Horned Frog Invitational',
#  'Bobcat Invitational',
#  'Tulsa Duels 2015',
#  'Tulsa Duels 2014',
#  'Don Kirby Elite Invitational',
#  'Stanford Twilight',
#  'UF Tom Jones Memorial',
#  'Red Raider Invitational',
#  'Texas A&M Triangular',
#  'Texas A&M Invitational I',
#  'Dunamis Sports Group College Classic II',
#  'Abilene Christian vs TCU',
#  'TCU vs Texas State',
#  'UIW Cross Country Invitational Dual Meet',
#  'UTA Bobby Lane Invitational',
#  'Concordia University Invitational',
#  '2015 UW Indoor Invitational',
#  'Lobo Collegiate Open',
#  'USATF Indoor Championships',
#  'Kehoe Twilight Meet 2018',
#  'Virginia v. Maryland, Bucknell, Georgetown',
#  'USF Bulls Invitational',
#  'Maryland Invitational',
#  'Big Ten Indoor Track and Field Championships',
#  'Spire NCAA D-1 Indoor Track & Field Classic',
#  'Cowboy Preview - Oklahoma  vs Arkansas',
#  'Cowboy Preview - Oklahoma vs Tulsa',
#  'Texas A&M Quadrangular Meet',
#  'J. D. Martin Invitational',
#  'Don Kirby Tailwind Open',
#  'NJCAA Championship',
#  '2018 Region VI Indoor Championships',
#  'Dr. Martin Luther King Jr. Collegiate Invitational',
#  'NJCAA DI Outdoor Track & Field National Championships',
#  '2017 Region VI Outdoor Championships',
#  'WT Classic and Multi',
#  '2017 Cowley Tiger Invite',
#  'ESU Spring Invitational',
#  'NJCAA Indoor Championships',
#  '2017 NJCAA Region VI Indoor Championships',
#  '2015 OBU Bison Invitational',
#  'MSSU Southern Stampede (D1)',
#  'SEC Outdoor Track and Field Championships',
#  'LSU Invitational',
#  'War Eagle Invitational 2018',
#  'Samford Alabama Track Challenge 2018',
#  'UAB Blazer Invitational',
#  'Rafer / JJK Collegiate Invitational',
#  'Chile Pepper Cross Country Festival',
#  'Incarnate Word vs TCU (Women)',
#  'North Texas vs TCU (Women)',
#  'Cowboy Preview - Oklahoma State vs Arkansas (Men)',
#  'Cowboy Preview - Oklahoma State vs Tulsa (Men)',
#  'UW Husky Classic',
#  'New Mexico Don Kirby Invitational',
#  'Carol Robinson Pentathlon',
#  'Razorback Combined',
#  'Carol Robinson Winter Pentathlon',
#  'ACC Outdoor Championships',
#  'FSU Relays (College)',
#  'UCF Black and Gold Challenge',
#  'NCAA Division I East Preliminary Round',
#  'ACC Outdoor Track & Field Championships',
#  'Seminole Twilight',
#  'Tennessee Relays',
#  'Clemson Indoor Invitational',
#  'UNF Twilight',
#  'Seminole Invitational',
#  'Rafer Johnson-Jackie Joyner Kersee Invitational',
#  'Florida State Relays',
#  '125th Penn Relays',
#  'Battle of the Blues',
#  'Clemson Tiger Paw Invitational',
#  'Hokie Invitational',
#  'Dick Taylor Carolina Cup',
#  'Queen City Invite',
#  'Elon Opener',
#  'Stonehill Skyhawk Invite',
#  'Ocean State Invitational',
#  'Boston University David Hemery Valentine Invitational',
#  'Boston University John Thomas Terrier Classic',
#  'Boston University Multi Team Meet',
#  'Beantown Challenge',
#  '2017 Ocean State Invitational',
#  'UMass Track & Field Meet',
#  'Boston University David Hemery Valentine Inv.',
#  'Crimson Elite',
#  'John Thomas Terrier Invitational',
#  'Mark T Young Invitational',
#  'David Hemery Valentine Invitational',
#  'Boston University Mulit Team Meet',
#  'Harvard Multi Meet',
#  'Sorlien Memorial Invitational',
#  'Boston University Opener',
#  '16th Annual CCSU Mini Meet',
#  'NEICAAA Cross Country Championship',
#  'Coast-to-Coast Battle in Beantown',
#  'Shawn M. Nassaney Memorial Invitational',
#  'NCAA Division I Northeast Region Cross Country Championships',
#  'Penn State Nationals Open',
#  'Stonehill Skyhawk Invitational',
#  'Sam Howell Invitational',
#  'Tufts Snowflake Classic',
#  '2018 Colonial Relays',
#  'NEICAAA Indoor Track & Field Championships',
#  'IC4A/ECAC Indoor Track & Field Championships',
#  '15th Annual CCSU Mini Meet',
#  '2019 Beantown Challenge',
#  'Coast-To-Coast Battle in Beantown',
#  '2017 Larry Ellis Invitational',
#  'Boston University Last Chance Qualifier',
#  '2017 Colonial Relays',
#  'Boston University Multi-Team Meet',
#  '2018 Larry Ellis Invitational',
#  'NCAA Division I East Region Preliminary Rounds',
#  '2018 Howlin Husky Invitational',
#  '14th Annual CCSU Mini Meet',
#  'Rothenberg - Brown Invitational',
#  'UMass Minuteman XC Invitational',
#  'Boston University Scarlet and White',
#  'CCSU Mini Meet',
#  'NEICAAA XC Championship',
#  'Coast to Coast Battle in Beantown',
#  '2015 UMass Minuteman XC Invitational',
#  '2016 IC4A/ECAC Indoor Track and Field Championships',
#  '2016 Armory Track Invitational (Colleges)',
#  'Larry Ellis Invite',
#  '2018 ECAC-IC4A Indoor Championships',
#  'NEICAAA Track and Field Outdoor Championship',
#  '2015 IC4A/ECAC Indoor Track & Field Championships',
#  'ACC Indoor Track and Field Championships',
#  'BU David Hemery Valentine Invitaional',
#  'Boston University John Thomas Terrier Invitational',
#  'Minuteman Cross Country Invitational',
#  '2019 Harvard Multi Meet',
#  'Miami Hurricane Alumni Invitational',
#  'Miami Power 5 Trailblazer Challenge',
#  'Miami Hurricane Invitational',
#  'South Florida Cross Country Invitational',
#  'UCF Knights Invite',
#  'Florida Atlantic University Collegiate Cross Country Invitational',
#  'USC Power 5 Challenge',
#  'UAB Vulcan Invitational',
#  'Florida Atlantic University Cross Country Invitational',
#  'URI Pentathlon',
#  'Doc Hale VT Elite',
#  'Clemson Tiger Paw Indoor',
#  '2017 Meyo Invitational',
#  'Virginia Tech Invitational',
#  'Miami Hurricane Twilight Invitational',
#  'Tiger Track Classic 2018',
#  'SEC Indoor Track & Field Championships',
#  'Commodore Invitational',
#  'SEC Outdoor Track & Field Championships',
#  'War Eagle Invititaional',
#  'Tiger Track Classic',
#  'SEC Championships',
#  'Auburn Invitational',
#  '2016 Mountain Dew Gator Cross Country Invitational',
#  'Tennessee Dual',
#  'Vanderbilt Commodore Invite',
#  'Mountains to Sea Duals',
#  'Georgia Invitational',
#  'War Eagle Invitational',
#  'South Florida Invitational',
#  'Florida State Cross Country Invitational/ Collge Pre-ACC',
#  '2015 Mountain Dew Gator Cross Country Invitational (College)',
#  'FAU Collegiate Cross Country Invitational',
#  '2019 Lenny Lyles-Clark Wood Invitational',
#  'Kentucky Track & Field Invitational',
#  'Louisville Invitational',
#  'Ole Miss Classic',
#  '37th Annual Victor Lopez Classic',
#  'Houston Spring Break Invitational',
#  'Kent State Doug Raymond Invite',
#  'FSU Relays',
#  '2019 Notre Dame Invitational',
#  'Gene Edmonds Open',
#  'LSU High Performance Meet',
#  'Vanderbilt Commodore Classic',
#  '2018 Lenny Lyles-Clark Wood Invitational',
#  '2018 Louisville Invitational',
#  'Vanderbilt Black and Gold',
#  '2018 Hoosier Hills',
#  'Lenny Lyles-Clark Wood Invitational',
#  '2017 Louisville Invitational',
#  '2017 Kentucky T&F Invitational',
#  'Commodore XC Classic',
#  'University of Dayton Flyer 5k',
#  '2019 Hoosier Hills',
#  '2018 Baldy Castillo Invitational',
#  'Illini Classic',
#  '2018 Notre Dame Invitational',
#  '2018 Kentucky Invitational',
#  'Vanderbilt Opener',
#  'Tennessee Rust Buster',
#  'Georgia Tech Yellow Jacket Invitational',
#  '2017 Notre Dame Invitational',
#  'Rankin/Poehlein Invitational',
#  'Memphis Tiger Invitational',
#  '2016 Louisville Invitational',
#  'Samford Invitational',
#  'Akron Invitational',
#  '2016 Indiana University Relays',
#  'Notre Dame Invitational 2016',
#  '2016 Kentucky Invitational',
#  '2016 WKU Hilltopper Relays',
#  'Commodore Classic',
#  '2017 Indiana University Relays',
#  'FAMU Relays',
#  'Big Bend Cross Country Invitational',
#  'UNF Invitational',
#  'Bobcat Inviational',
#  'Clemson Orange & Purple Elite',
#  'Boston University vs Florida State XC',
#  'North Florida Invitational',
#  'Yellow Jacket Invitational',
#  'Clemson Orange & Purple Invitational',
#  'Clemson Bob Pollock Indoor Invitational',
#  'Covered Bridge CC Open Meet',
#  '2017 Virgina Tech Alumni Invitational',
#  'Covered Bridge CC Meet',
#  'Bulls Invitational',
#  'Auburn Invitational 2015',
#  'Alabama Crimson Classic',
#  'Virginia Tech Alumni Invitational',
#  'adidas XC Challenge',
#  'Jace LaCoste- Mississippi State Invitational',
#  'Covered Bridge Open CC Meet',
#  'FSU Cross Country Invitational (College)',
#  'Charlotte Invitational',
#  'Virginia Tech Alumni Inv.',
#  '2019 Illini Invitational',
#  'Louisville Twilight',
#  '2015 UT Challenge',
#  'Georgia Tech Invitational',
#  'ACC-Big Ten Challenge',
#  'Georgia Bulldog Invitational',
#  'Spec Towns Invitational',
#  'Berry Invitational',
#  'Torrin Lawrence Memorial',
#  'Tiger Track Classic 2019',
#  'BSC Panther Indoor Icebreaker',
#  'Bulldog SEC Preview',
#  'JSU Struts XC Season Opener',
#  'Alabama Relays',
#  'Clemson Orange and Purple Indoor',
#  'Georgia Spec Towns National Team Invitational',
#  'Georgia v. Georgia Tech',
#  'Kennesaw State v. Georgia Tech',
#  'JSU Foothills Cross Country Invitational',
#  'Paul Short Open',
#  'Samford University Invitational',
#  'Gene Mullin Invitational',
#  'Vanderbilt Indoor Invitational',
#  'Berry College Invitational',
#  'Joe Walker Classic',
#  'Virginia Grand Prix',
#  'Duke Invitational',
#  'Upstate Invitational',
#  '2014 Mountain Dew Gator Cross Country Invitational (College)',
#  '2014 UGA Cross Country Invitational',
#  'Hokie Open',
#  'ECU Pirates XC Invitational',
#  'HPU VertKlasse Meeting',
#  'Virginia Tech Challenge',
#  'Alabama Crimson Classic XC DI Meet 2014',
#  'Wake Forest Outdoor Opener',
#  'Orange & Purple Classic',
#  'Dr Sander Invitational Columbia Challenge',
#  'ECU Pirates XC invitational',
#  '2017 WINTHROP/ADIDAS Cross Country Invitational',
#  'Bull City Classic',
#  'UCS Invitational',
#  'Great American XC Festival',
#  'Liberty Elite Invitational',
#  'Dick Taylor UNC Challenge',
#  'Roanoke Tune Up',
#  'High Point University Vert XC Invitational',
#  '2016 Sycamore Cross Country Invitational',
#  'Duke Alumni Meet',
#  'Air Force Open',
#  '3 Stripe Invitational',
#  'Spec Towns Invitational 2016',
#  'Princeton Inter Regional',
#  'Clemson Last Chance Indoor Invitational',
#  'University of South Alabama Invitational',
#  'Wolfpack Last Chance',
#  'Pacific Beach Intercollegiate',
#  'adidas XC Challenge Duke Vs. Charleston Southern',
#  'adidas XC Challenge Duke Vs. Davidson',
#  'adidas XC Challenge Duke Vs. East Carolina',
#  'adidas XC Challenge Duke Vs. Elon',
#  'adidas XC Challenge Duke Vs. Gardner-Webb',
#  'adidas XC Challenge Duke Vs. N. Carolina A&T',
#  'adidas XC Challenge Duke Vs. N.C. Central',
#  'adidas XC Challenge Duke Vs. Richmond',
#  'adidas XC Challenge Duke Vs. UNC-Greensboro',
#  'adidas XC Challenge Duke Vs. VCU',
#  'adidas XC Challenge Duke Vs. Wake Forest',
#  'adidas XC Challenge NC State Vs. Duke',
#  'Dr. Sander Invitational Armory Challenge (College/Open)',
#  'Royals XC Challenge',
#  'Mt. SAC Relays/CA Invitational Multi Events',
#  'Tobacco Road Cup(Multis)',
#  'UNF East Region Preview',
#  'Notre Dame Cross Country Invitational',
#  'Gamecock Invitational Outdoor',
#  'Carolina Challenge',
#  'UNF Spring Break Invitational',
#  '49er Classic',
#  'Furman XC Classic',
#  'Eye Opener 2016',
#  'FURMAN XC CLASSIC',
#  'North Florida Spring Break Invitational',
#  'Charlotte 49er Classic',
#  'Clemson Orange & Purple Open',
#  'Joe Piane Notre Dame Cross Country Invitational',
#  'Winthrop Early Season Challenge',
#  'Alan Connie Shamrock Invitational',
#  'Clemson Orange & Purple Classic',
#  'Gamecock Invitational',
#  'Bob Pollock Invitational',
#  '2018 Dartmouth Relays - College & Open',
#  'XIX Alan Connie Shamrock Invitational',
#  '2nd Annual Furman Classic',
#  'Clemson XC Tiger Invite',
#  '2017 Dartmouth Relays - College & Open',
#  'U Mass Amherst Minuteman Invitational',
#  'Sam Howell (College)',
#  'BU Scarlet and White',
#  '2016 Dartmouth Relays - College/Open',
#  'Chile Pepper XC Festival',
#  'NCAA Division I Mid-Atlantic Region Cross Country Championships',
#  '17th Annual LHU Invitational/Open',
#  'Charlotte Opener',
#  'Harry Groves Spiked Shoe - Bucknell vs West Virginia',
#  'Harry Groves Spiked Shoe - Georgetown vs West Virginia',
#  'Harry Groves Spiked Shoe - Penn State vs West Virginia',
#  'Harry Groves Spiked Shoe - Pitt vs West Virginia',
#  'Harry Groves Spiked Shoe - Syracuse vs West Virginia',
#  'Marty Pushkin Open',
#  'Paul Short - Gold',
#  'Cornell vs West Virginia',
#  'Georgetown vs West Virginia',
#  'Penn State vs West Virginia',
#  'Rutgers vs West Virginia',
#  "St Joseph's vs West Virginia",
#  'Syracuse vs West Virginia',
#  'WVU Alumni Open',
#  'Spiked Shoe',
#  'Bison Outdoor Classic',
#  'Lehigh Invitational',
#  'Mountaineer Open',
#  'State Farm Friends of Track and Field Mountaineer Showcase',
#  'West Virginia Open',
#  '2019 SPIRE NCAA D-1 Classic',
#  'Akron Invitational (Collegiate)',
#  'Youngstown State Invite',
#  'Univ. of Akron - College Invitational',
#  'Youngstown State College Invite',
#  'WVU Open',
#  '2016 Marty Pushkin Open',
#  'Penn State Tune-Up',
#  'Marty Pushkin Track Classic',
#  'George Mason Spring Invitational',
#  'Spring Invitational',
#  'Wake Forest Open',
#  'High Point Panthers Team Challenge',
#  '9th Annual Gator Invitational',
#  'Larry Ellis Invitational',
#  'Spring Invite',
#  'Ohio Cherry Blossom Invitational',
#  'Cal U Early Bird',
#  'WVU Gold - Blue',
#  'SPIRE NCAA D-1 Indoor T&F Invitational',
#  'Penn State National Invitational',
#  'YSU Indoor Invitational',
#  'WVU Gold-Blue',
#  'WVU Invitational',
#  'Penn State Indoor Relays',
#  'YSU Indoor Invite',
#  'YSU Penguin Icebreaker',
#  'PSU Tune-Up',
#  'Tennessee Challenge',
#  '2016 Billy Hayes Invitational',
#  'Swarthmore Final Qualifier',
#  'Ohio State - Jesse Owens Classic',
#  'Thundering Herd Invitational',
#  'Columbia Final Qualifier',
#  'Mason Spring Invitational',
#  '2015 UNF Spring Break Invitational',
#  'Texas Tech Masked Rider Invite',
#  'ACU Wes Kittley Invitational',
#  'Red Raider Invite',
#  'NCAA Division I Mountain Region Cross Country Championships',
#  'TTU Masked Rider Open',
#  'Corky/Crofoot Shootout',
#  'ACU Wes Kittley Invitational & Multi 2019',
#  'Texas Tech Masked Rider Open',
#  'Wes Kittley Invitational',
#  'Fearless Champion Open',
#  'Dunamis Sports Group College Classic I',
#  '2017 adidas Classic',
#  'Texas Tech - New Mexico State Duel',
#  'ACU Naimadu Classic',
#  'WT Classic & Multi',
#  'Texas Tech Red Raider Open',
#  'West Texas A&M Twilight',
#  'Wes Kittley Invitational 2015',
#  'Texas Tech Outdoor Open',
#  'Texas Tech Indoor Open',
#  'Santa Clara Bronco Invitational',
#  'Illinois State Redbird Invitational',
#  'NJCAA Region XI Championships',
#  'MVC Indoor Track & Field Championships',
#  'Minnesota State - Alumni Open',
#  '2016 NJCAA Outdoor National Championships',
#  '2018 Meyo Invitational',
#  '2016 Region XI Outdoor Championships',
#  'Texas Tech Red & Black Open',
#  'Terre Haute Double Dual',
#  'EIU Early Bird 2017',
#  'TTU UTEP CC Dual',
#  '2017 MVC Outdoor Track and Field Championships',
#  'Santa Clara University Bronco Invitational (Invite)',
#  '2016 Cornell Outdoor Invite',
#  'ACU Wildcats Invitational',
#  'NJCAA Indoor Track and Field Championships',
#  'NJCAA Region XI Indoor Championships',
#  'ACU Wildcat Open',
#  'ASU Red Wolf Open',
#  'Mississippi State Bulldog Relays',
#  'Rhodes Invitational',
#  'Jack Johnson Classic',
#  'Gibson Invitational (OVC vs. MVC Challenge)',
#  'NMJC Ross Black Open',
#  'Angelo State David Noble Relays',
#  'UTEP Springtime 2017',
#  '2018 KMS Invitational',
#  'Jim Emmerich Invitational',
#  'Iowa Duals',
#  'Minnesota State Alumni Open',
#  '2016 South Plains College Cross Country Invitational',
#  'EIU Big Blue Classic 2017',
#  '2015 Armory Track Invitational',
#  'NMJC Indoor Invitational',
#  'Ole Miss/ Joe Walker Invitational',
#  '2017 MVC Indoor Track & Field Championships',
#  '2016 NJCAA Division I National Championships',
#  '2016 McMurry Bill Libby Invitational (College Only)',
#  'ACU Oliver Jackson Twilight Meet',
#  'Ross Black Open',
#  '2018 Desert Heat Classic',
#  'Chile Pepper Cross Country Fesitval',
#  'UTEP Springtime 2016',
#  'South Plains College Indoor Invite',
#  'Texas Tech - New Mexico State - UTEP Double Dual',
#  'John Craft Invitational 2017',
#  'Terre Haute Double Dual Meet',
#  'ACU Oliver Jackson Twilight 2018',
#  'Bill Libby/McMurry University Cross Country Invitational',
#  'Conference USA Indoor Track & Field Championships',
#  'EIU Early Bird 2016',
#  '2018 American Southwest Conference Championships',
#  '2018 East Texas Invitational',
#  'McMurry War Hawk Classic',
#  'NCAA Division III South/Southeast Region Cross Country Championships',
#  'ASC Cross Country Championships',
#  'University Of Dallas Invitational',
#  'Oklahoma Baptist University Cross Country Invitational',
#  '2017 Saints Invitational',
#  'Hardin-Simmons University Cross Country Invitational',
#  '2017 McMurry University Bill Libby Invitational',
#  'NMSU UTEP CC Dual',
#  'Lori Fitzgerald 2017',
#  '2017 UNM Lobo Cross Country Invitational (College)',
#  '2017 NCCAA National Championships',
#  'ACU Oliver Jackson Twilight',
#  '2017 Conference USA Outdoor Track & Field Championship',
#  '2017 American Southwest Conference Championships',
#  '2017 McMurry Open',
#  'Hardin-Simmons Invitational',
#  'Jim Bush Collegiate Invitational',
#  '2017 War Hawk Classic',
#  'Marc Randle Classic',
#  '2017 NCCAA Indoor Track & Field Championship',
#  'MSSU Southern Invitational',
#  'NCCAA Cross Country National Championships',
#  'South Plains College Cross Country Invite',
#  'Pure Athletics/NTC Sprint Elite Meet',
#  'ETBU TX D-III Championship',
#  'Wisconsin Twilight',
#  'NCCAA National Championships 2016',
#  'MEAC Outdoor Track & Field Championships',
#  'ASU David Noble Relays',
#  'CUSA Championship',
#  '2016 War Hawk Classic',
#  'Conference USA Championship',
#  'Joe Gillespie Invitational',
#  'Trinity Open 2016',
#  '1st Annual Indoor Gorilla Classic',
#  'MN / WI Dual',
#  'MSSU Southern Invite',
#  'NCCAA XC Championships',
#  'Big Ten Outdoor Championships',
#  'Wisconsin Alumni Classic',
#  ...]

# %%
# flag conference, regional and national championship meet appearances
# flag USA Indoor and Outdoor Championships
# flag olympic and world's appearances


# world or olympic championship appearance
df['oly_or_world_champs'] = (((df.Location.str.contains('IAAF')) & ~(df.Location.str.contains('U20'))) |
                              (df.Location.str.contains('Olympic Games')))

# USA Championship
df['usa_championship'] = (((df.Location.str.contains('Trial')) | (df.Location.str.contains('USATF'))) &
                          (~(df.Location.str.contains('U20'))) &
                          (~(df.Location.str.contains('Junior'))))


# conference championships for the power 5
df['conf_championship'] = (((df.Location.str.contains('Big 12')) & (df.Location.str.contains('Champ'))) | 
                          ((df.Location.str.contains('Big Ten')) & (df.Location.str.contains('Champ'))) |
                          ((df.Location.str.contains('Pac')) & (df.Location.str.contains('Champ'))) |
                          ((df.Location.str.contains('SEC')) & (df.Location.str.contains('Champ'))) |
                          ((df.Location.str.contains('ACC ')) & (df.Location.str.contains('Champ'))))

# Indoor track nationals for DI only
df['indoor_track_nationals'] = ((df.Location.str.contains('NCAA Division I Indoor Championships')) | 
                               (df.Location.str.contains('NCAA Division I Indoor Track & Field Championships')))

# West / East NCAA Prelim Rounds (Regionals for track) for DI only
df['outdoor_track_regionals'] = (df.Location.str.contains('Round'))

# NCAAs for Outdoors DI only
df['outdoor_track_nationals'] = ((df.Location.str.contains('NCAA Division I Track & Field Championships')) | 
                                (df.Location.str.contains('NCAA Division I Championships')) | 
                                (df.Location.str.contains('NCAA Division I Outdoor Track & Field Championships')) | 
                                (df.Location.str.contains('NCAA Division I Outdoor Championships')) | 
                                (df.Location.str.contains('NCAA Division I National Championships')))

# XC Regionals for DI only
df['xc_regionals'] = ((df.Location.str.contains('Region')) &
                     (df.Location.str.contains('Champ')) & 
                     (df.Location.str.contains('NCAA')) &
                     (~(df.Location.str.contains('II'))))

# XC Nationals for DI only
df['xc_nationals'] = ((df.Location.str.contains('NCAA Division I Cross Country Championships')) |
                     (df.Location.str.contains('NCAA DI Cross Country Championships')))

# IAAF World Juniors
df['world_jr_championship'] = ((df.Location.str.contains('World')) &
                              (df.Location.str.contains('U20')))

# USATF Junior Championships
df['usa_jr_championship'] = ((df.Location.str.contains('USATF')) & 
                             ((df.Location.str.contains('Junior')) | (df.Location.str.contains('U20'))))

# %% [markdown]
# ### Converting Time to Seconds

# %%
# fixing two incorrect values

df.is_field_event = df.is_field_event + ((df['Performance'] == '14m') | (df['Performance'] == '2m'))

# %%
# fix a couple of columns
df.is_multi_event = df.is_multi_event.map({1: True, 0: False})
df.is_relay = df.is_relay.map({1: True, 0: False})
df.has_hurdles = df.has_hurdles.map({1: True, 0: False})
df.is_field_event = df.is_field_event.map({1: True, 0: False})

# %%
df.Performance
# Out:
# 0         02:59.0
# 1         02:51.0
# 2         02:11.7
# 3         02:11.1
# 4         02:10.0
#            ...
# 195141       7.53
# 195142      24.36
# 195143    03:45.5
# 195144       7.61
# 195145    03:43.0
# Name: Performance, Length: 187176, dtype: object

# %%
df.head()
# Out:
#                  Name   Grade            Team              Location  \
# 0  Abbie Hetherington  (Sr-4)  Oklahoma State  Big 12 Championships
# 1  Abbie Hetherington  (Sr-4)  Oklahoma State  Big 12 Championships
# 2  Abbie Hetherington  (Sr-4)  Oklahoma State    Arkansas Qualifier
# 3  Abbie Hetherington  (Sr-4)  Oklahoma State    2019 Husky Classic
# 4  Abbie Hetherington  (Sr-4)  Oklahoma State  2019 UW Invitational
#
#                     Date Events Performance  Place event  is_relay  ...  \
# 0   02/22 - Feb 23, 2019   1000     02:59.0      8  1000     False  ...
# 1   02/22 - Feb 23, 2019   1000     02:51.0      4  1000     False  ...
# 2              15-Feb-19    800     02:11.7      3   800     False  ...
# 3  02/08 - Feb  09, 2019    800     02:11.1     15   800     False  ...
# 4   01/25 - Jan 26, 2019    800     02:10.0     18   800     False  ...
#
#    oly_or_world_champs  usa_championship  conf_championship  \
# 0                False             False               True
# 1                False             False               True
# 2                False             False              False
# 3                False             False              False
# 4                False             False              False
#
#   indoor_track_nationals  outdoor_track_regionals  outdoor_track_nationals  \
# 0                  False                    False                    False
# 1                  False                    False                    False
# 2                  False                    False                    False
# 3                  False                    False                    False
# 4                  False                    False                    False
#
#    xc_regionals  xc_nationals  world_jr_championship  usa_jr_championship
# 0         False         False                  False                False
# 1         False         False                  False                False
# 2         False         False                  False                False
# 3         False         False                  False                False
# 4         False         False                  False                False
#
# [5 rows x 49 columns]

# %%
# filter by performances that are purdy points eligible

df['purdy_points_eligible'] = (~df.xc_season_2013 * 
                                 ~df.xc_season_2014 * 
                                 ~df.xc_season_2015 * 
                                 ~df.xc_season_2016 * 
                                 ~df.xc_season_2017 * 
                                 ~df.xc_season_2018 *
                                 ~df.is_field_event * 
                                 ~df.is_relay * 
                                 ~df.has_hurdles * 
                                 ~df.is_multi_event)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:193: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   op=op_str, alt_op=unsupported[op_str]

# %%
# create purdy points eligible performance times
df.purdy_points_eligible = df.Performance * df.purdy_points_eligible

# %%
df['is_wind_aided'] = df.purdy_points_eligible.str.contains('W|w')

# %%
df.purdy_points_eligible = df.purdy_points_eligible * ~df.is_wind_aided

# %%
df[df.purdy_points_eligible.str.contains('h|H')]
# Out:
#                     Name                   Grade           Team  \
# 42178     Mckenna  Smith  (Red Shirt/Unattached)  West Virginia
# 42418   Hayley  Jackson                   (Jr-3)  West Virginia
# 42663  Michaela  Ashford                  (Jr-3)  West Virginia
# 42867  Marianne  Abdalah                  (So-2)  West Virginia
# 42895     Shamoya Mcneil                  (Sr-4)  West Virginia
#
#                           Location      Date    Events Performance  Place  \
# 42178  Marty Pushkin Track Classic  2-Dec-17       500     1:20.2H      1
# 42418  Marty Pushkin Track Classic  2-Dec-17  1609.344     5:11.1H      1
# 42663  Marty Pushkin Track Classic  2-Dec-17        60        7.7H      3
# 42867  Marty Pushkin Track Classic  2-Dec-17      3000    11:06.4H      1
# 42895  Marty Pushkin Track Classic  2-Dec-17        60        7.7H      5
#
#       event  is_relay  ...  conf_championship  indoor_track_nationals  \
# 42178   500     False  ...              False                   False
# 42418  Mile     False  ...              False                   False
# 42663    60     False  ...              False                   False
# 42867  3000     False  ...              False                   False
# 42895    60     False  ...              False                   False
#
#        outdoor_track_regionals outdoor_track_nationals  xc_regionals  \
# 42178                    False                   False         False
# 42418                    False                   False         False
# 42663                    False                   False         False
# 42867                    False                   False         False
# 42895                    False                   False         False
#
#        xc_nationals  world_jr_championship  usa_jr_championship  \
# 42178         False                  False                False
# 42418         False                  False                False
# 42663         False                  False                False
# 42867         False                  False                False
# 42895         False                  False                False
#
#        purdy_points_eligible  is_wind_aided
# 42178                1:20.2H          False
# 42418                5:11.1H          False
# 42663                   7.7H          False
# 42867               11:06.4H          False
# 42895                   7.7H          False
#
# [5 rows x 51 columns]

# %%
# calculate seconds and make a new column from the times given
def time_to_seconds(performance):
    performance = str(performance)
    if performance == '':
        return 0
    else:
        performance = performance.lower().strip('abcdefghijklmnopqrstuvwxyz')
        if ':' in performance:
            performance = performance.split(':')
            return float(performance[0])*60 + float(performance[1])
        else:
            return float(performance)

# %%
# a column of the number of seconds for purdy points eligible times
df['seconds'] = df.purdy_points_eligible.apply(time_to_seconds)

# %%
df.seconds
# Out:
# 0         179.00
# 1         171.00
# 2         131.70
# 3         131.10
# 4         130.00
#            ...
# 195141      7.53
# 195142     24.36
# 195143      0.00
# 195144      7.61
# 195145      0.00
# Name: seconds, Length: 187176, dtype: float64

# %%
df['meters'] = df.seconds.apply(lambda x: False if x == 0 else True) * df.Events

# %%
df.meters.unique()
# Out:
# array(['1000', '800', '', '1500', '1609.344', '400', '600', '548.64',
#        '5000', '10000', '3000', '100', '200', '60', '300', '55', '1600',
#        '500', '914.4'], dtype=object)

# %%
# 0 meters if event is not purdy points elgibile
df['meters'] = df['meters'].apply(lambda x: 0 if x == '' else float(x))

# %%
df.meters.unique()
# Out:
# array([ 1000.   ,   800.   ,     0.   ,  1500.   ,  1609.344,   400.   ,
#          600.   ,   548.64 ,  5000.   , 10000.   ,  3000.   ,   100.   ,
#          200.   ,    60.   ,   300.   ,    55.   ,  1600.   ,   500.   ,
#          914.4  ])

# %% [markdown]
# ## Purdy Points

# %% [markdown]
# https://www.cs.uml.edu/~phoffman/xcinfo3.html

# %%
# Preparing for Purdy points function
# code translated from link above by Declan McDonnell
def frac(d):
    if (d <110):
        return 0
    else:
        laps = int(d/400)
        meters = d - laps*400
        if (meters <= 50):
            partlap = 0
        elif (meters <= 150):
            partlap = meters - 50
        elif (meters <=250):
            partlap = 100
        elif (meters <=350):
            partlap = 100 + (meters - 250)
        elif (meters <=400):
            partlap = 200
    tmeters= laps*200 + partlap
    return (tmeters/d)

# %%
# Purdy points function
# code translated from link above by Declan McDonnell
def purdy(dist, tsec):
    i = 0
    ptable= [40.0,11.000, 50.0,10.9960, 60.0,10.9830, 70.0,10.9620,
            80.0,10.934, 90.0,10.9000,100.0,10.8600,110.0,10.8150,
            120.0,10.765,130.0,10.7110,140.0,10.6540,150.0,10.5940,
            160.0,10.531,170.0,10.4650,180.0,10.3960,200.0,10.2500,
            220.0,10.096,240.0, 9.9350,260.0, 9.7710,280.0, 9.6100,
            300.0, 9.455,320.0, 9.3070,340.0, 9.1660,360.0, 9.0320,
            380.0, 8.905,400.0, 8.7850,450.0, 8.5130,500.0, 8.2790,
            550.0, 8.083,600.0, 7.9210,700.0, 7.6690,800.0, 7.4960,
            900.0,7.32000, 1000.0,7.18933, 1200.0,6.98066, 1500.0,6.75319,
            2000.0,6.50015, 2500.0,6.33424, 3000.0,6.21913, 3500.0,6.13510,
            4000.0,6.07040, 4500.0,6.01822, 5000.0,5.97432, 6000.0,5.90181,
            7000.0,5.84156, 8000.0,5.78889, 9000.0,5.74211,10000.0,5.70050,
           12000.0,5.62944,15000.0,5.54300,20000.0,5.43785,25000.0,5.35842,
           30000.0,5.29298,35000.0,5.23538,40000.0,5.18263,50000.0,5.08615,
            60000.0,4.99762,80000.0,4.83617,100000.0,4.68988,
                                      -1.0,0.0 ]
    c1=0.20
    c2=0.08
    c3=0.0065
    d=0.1
    i = 0
    while dist > d and d>0:
        d=ptable[i]
        i+=2
    if (d<1):
        return 0
    i+= -2
    d3=ptable[i]
    t3= d3/ptable[i+1]
    if d3 >= 50.0:
        d1=ptable[i-2]
        t1=d1/ptable[i-1]
    else:
        d1 = 0
        t1 = 0
    t = t1 + (t3-t1)*(dist-d1)/(d3-d1)
    v = dist/t
    t950 = t +c1+c2*v +c3*frac(dist)*v*v
    k = 0.0654 - 0.00258*v
    a = 85/k
    b = 1-950/a
    p = a*(t950/tsec - b)
    return p

# %%
purdy_dict = {}
for i, j in df[['seconds', 'meters']].iterrows():
#     print(i)
#     print(j['Meters'])
#     print(j['duration_seconds'])
#     print('')
    purdy_dict[i] = [purdy(j['meters'], j['seconds'])]

# %%
df = pd.concat([df, pd.np.round(pd.DataFrame(purdy_dict).T, 2)], axis=1)

# %%
df.head(30)
# Out:
#                   Name   Grade            Team  \
# 0   Abbie Hetherington  (Sr-4)  Oklahoma State
# 1   Abbie Hetherington  (Sr-4)  Oklahoma State
# 2   Abbie Hetherington  (Sr-4)  Oklahoma State
# 3   Abbie Hetherington  (Sr-4)  Oklahoma State
# 4   Abbie Hetherington  (Sr-4)  Oklahoma State
# 5   Abbie Hetherington  (Sr-4)  Oklahoma State
# 6   Abbie Hetherington  (Sr-4)  Oklahoma State
# 7   Abbie Hetherington  (Sr-4)  Oklahoma State
# 8   Abbie Hetherington  (Sr-4)  Oklahoma State
# 9   Abbie Hetherington  (Sr-4)  Oklahoma State
# 10  Abbie Hetherington  (Sr-4)  Oklahoma State
# 12  Abbie Hetherington  (Sr-4)  Oklahoma State
# 14  Abbie Hetherington  (Sr-4)  Oklahoma State
# 15  Abbie Hetherington  (Sr-4)  Oklahoma State
# 16  Abbie Hetherington  (Sr-4)  Oklahoma State
# 17  Abbie Hetherington  (Sr-4)  Oklahoma State
# 18  Abbie Hetherington  (Sr-4)  Oklahoma State
# 19  Abbie Hetherington  (Sr-4)  Oklahoma State
# 20  Abbie Hetherington  (Sr-4)  Oklahoma State
# 21  Abbie Hetherington  (Sr-4)  Oklahoma State
# 22  Abbie Hetherington  (Sr-4)  Oklahoma State
# 23  Abbie Hetherington  (Sr-4)  Oklahoma State
# 25  Abbie Hetherington  (Sr-4)  Oklahoma State
# 26  Abbie Hetherington  (Sr-4)  Oklahoma State
# 27  Abbie Hetherington  (Sr-4)  Oklahoma State
# 28  Abbie Hetherington  (Sr-4)  Oklahoma State
# 29  Abbie Hetherington  (Sr-4)  Oklahoma State
# 30  Abbie Hetherington  (Sr-4)  Oklahoma State
# 31  Abbie Hetherington  (Sr-4)  Oklahoma State
# 32  Abbie Hetherington  (Sr-4)  Oklahoma State
#
#                                              Location                   Date  \
# 0                                Big 12 Championships   02/22 - Feb 23, 2019
# 1                                Big 12 Championships   02/22 - Feb 23, 2019
# 2                                  Arkansas Qualifier              15-Feb-19
# 3                                  2019 Husky Classic  02/08 - Feb  09, 2019
# 4                                2019 UW Invitational   01/25 - Jan 26, 2019
# 5                               Arkansas Invitational              11-Jan-19
# 6                               Arkansas Invitational              11-Jan-19
# 7                  Big 12 Cross Country Championships              26-Oct-18
# 8                         Arturo Barrios Invitational              13-Oct-18
# 9   Nuttycombe Wisconsin Invitational Presented By...              28-Sep-18
# 10                        NCAA West Preliminary Round   05/24 - May 26, 2018
# 12                                  Arkansas Twilight               4-May-18
# 14                       National Relay Championships   04/27 - Apr 28, 2018
# 15                        John McDonnell Invitational   04/13 - Apr 14, 2018
# 16                              Stanford Invitational   03/30 - Mar 31, 2018
# 17                              Stanford Invitational   03/30 - Mar 31, 2018
# 18  NCAA Division I Indoor Track & Field Champions...   03/09 - Mar 10, 2018
# 19          Big 12 Indoor Track & Field Championships   02/23 - Feb 24, 2018
# 20          Big 12 Indoor Track & Field Championships   02/23 - Feb 24, 2018
# 21                                 2018 Husky Classic   02/09 - Feb 10, 2018
# 22                             Razorback Invitational   01/26 - Jan 27, 2018
# 23                             Razorback Invitational   01/26 - Jan 27, 2018
# 25             NCAA Division I West Preliminary Round   05/25 - May 27, 2017
# 26             NCAA Division I West Preliminary Round   05/25 - May 27, 2017
# 27         Big 12 Outdoor Track & Field Championships   05/12 - May 14, 2017
# 28                                  Arkansas Twilight               5-May-17
# 29                                  Arkansas Twilight               5-May-17
# 30              2017 Drake Relays presented by Hy-Vee   04/26 - Apr 29, 2017
# 31                              Stanford Invitational  03/31 - Apr  01, 2017
# 32                              Stanford Invitational  03/31 - Apr  01, 2017
#
#     Events Performance  Place   event  is_relay  ...  outdoor_track_nationals  \
# 0     1000     02:59.0      8    1000     False  ...                    False
# 1     1000     02:51.0      4    1000     False  ...                    False
# 2      800     02:11.7      3     800     False  ...                    False
# 3      800     02:11.1     15     800     False  ...                    False
# 4      800     02:10.0     18     800     False  ...                    False
# 5      800     02:11.1      1     800     False  ...                    False
# 6    4x400     03:53.7      9   4x400      True  ...                    False
# 7     6000     21:18.4     26      6K     False  ...                    False
# 8     6000     22:09.1     57      6K     False  ...                    False
# 9     6000     21:59.7     40      6K     False  ...                    False
# 10     800     02:19.2     48     800     False  ...                    False
# 12     800     02:08.5      3     800     False  ...                    False
# 14     DMR     11:47.5      6     DMR      True  ...                    False
# 15     800     02:11.4      4     800     False  ...                    False
# 16     800     02:09.2     20     800     False  ...                    False
# 17    1500     04:38.8      8    1500     False  ...                    False
# 18     DMR     11:04.7      6     DMR      True  ...                    False
# 19    1000     02:47.7      5    1000     False  ...                    False
# 20    1000     02:49.8      5    1000     False  ...                    False
# 21     800     02:10.0     14     800     False  ...                    False
# 22     800     02:09.6     15     800     False  ...                    False
# 23   4x400     04:02.6     11   4x400      True  ...                    False
# 25     800     02:11.6     22     800     False  ...                    False
# 26     800     02:08.8     21     800     False  ...                    False
# 27    1500     04:39.3     15    1500     False  ...                    False
# 28     800     02:09.6      4     800     False  ...                    False
# 29   4x400     03:45.9      1   4x400      True  ...                    False
# 30  4x1600     19:07.1      1  4x1600      True  ...                    False
# 31     800     02:09.9     21     800     False  ...                    False
# 32    1500     04:22.6     10    1500     False  ...                    False
#
#     xc_regionals  xc_nationals world_jr_championship  usa_jr_championship  \
# 0          False         False                 False                False
# 1          False         False                 False                False
# 2          False         False                 False                False
# 3          False         False                 False                False
# 4          False         False                 False                False
# 5          False         False                 False                False
# 6          False         False                 False                False
# 7          False         False                 False                False
# 8          False         False                 False                False
# 9          False         False                 False                False
# 10         False         False                 False                False
# 12         False         False                 False                False
# 14         False         False                 False                False
# 15         False         False                 False                False
# 16         False         False                 False                False
# 17         False         False                 False                False
# 18         False         False                 False                False
# 19         False         False                 False                False
# 20         False         False                 False                False
# 21         False         False                 False                False
# 22         False         False                 False                False
# 23         False         False                 False                False
# 25         False         False                 False                False
# 26         False         False                 False                False
# 27         False         False                 False                False
# 28         False         False                 False                False
# 29         False         False                 False                False
# 30         False         False                 False                False
# 31         False         False                 False                False
# 32         False         False                 False                False
#
#     purdy_points_eligible  is_wind_aided  seconds  meters       0
# 0                 02:59.0          False    179.0  1000.0  555.10
# 1                 02:51.0          False    171.0  1000.0  621.51
# 2                 02:11.7          False    131.7   800.0  613.79
# 3                 02:11.1          False    131.1   800.0  620.70
# 4                 02:10.0          False    130.0   800.0  633.53
# 5                 02:11.1          False    131.1   800.0  620.70
# 6                                  False      0.0     0.0    0.00
# 7                                  False      0.0     0.0    0.00
# 8                                  False      0.0     0.0    0.00
# 9                                  False      0.0     0.0    0.00
# 10                02:19.2          False    139.2   800.0  532.48
# 12                02:08.5          False    128.5   800.0  651.37
# 14                                 False      0.0     0.0    0.00
# 15                02:11.4          False    131.4   800.0  617.24
# 16                02:09.2          False    129.2   800.0  642.99
# 17                04:38.8          False    278.8  1500.0  595.44
# 18                                 False      0.0     0.0    0.00
# 19                02:47.7          False    167.7  1000.0  650.74
# 20                02:49.8          False    169.8  1000.0  632.01
# 21                02:10.0          False    130.0   800.0  633.53
# 22                02:09.6          False    129.6   800.0  638.24
# 23                                 False      0.0     0.0    0.00
# 25                02:11.6          False    131.6   800.0  614.94
# 26                02:08.8          False    128.8   800.0  647.77
# 27                04:39.3          False    279.3  1500.0  592.91
# 28                02:09.6          False    129.6   800.0  638.24
# 29                                 False      0.0     0.0    0.00
# 30                                 False      0.0     0.0    0.00
# 31                02:09.9          False    129.9   800.0  634.70
# 32                04:22.6          False    262.6  1500.0  682.87
#
# [30 rows x 54 columns]

# %%
df.rename(columns={0:'purdy_points'}, inplace=True)

# %%
# for fun; best and worst performances in recent years from the power 5's
df.sort_values('purdy_points', ascending=False)[['Name', 'Team', 'Location', 'Date', 'Events', 'Performance', 'Place', 'purdy_points']]
# Out:
#                     Name            Team  \
# 44306     Divine Oduduru      Texas Tech
# 44597     Divine Oduduru      Texas Tech
# 101582  Cravon Gillespie          Oregon
# 44307     Divine Oduduru      Texas Tech
# 87412       Quincy  Hall  South Carolina
# ...                  ...             ...
# 134697     Venida Fagan         Maryland
# 16762         Kira White  Oklahoma State
# 738       Maxwell Willis          Baylor
# 72117     Brianna Duncan          Oregon
# 105470    Brianna Duncan          Oregon
#
#                                                  Location  \
# 44306   NCAA Division I Outdoor Track & Field Champion...
# 44597                        Michael Johnson Invitational
# 101582  NCAA Division I Outdoor Track & Field Champion...
# 44307   NCAA Division I Outdoor Track & Field Champion...
# 87412                       Gamecock Invitational Outdoor
# ...                                                   ...
# 134697                                   USF Invitational
# 16762                                  Jim Click Shootout
# 738                            USATF Junior Championships
# 72117   NCAA Division I Outdoor Track & Field Champion...
# 105470  NCAA Division I Outdoor Track & Field Champion...
#
#                          Date Events Performance  Place  purdy_points
# 44306   06/05 - Jun  08, 2019    200       19.73      1       1076.48
# 44597    04/19 - Apr 20, 2019    200       19.76      1       1072.97
# 101582          Jun 5-8, 2019    200       19.93      2       1053.31
# 44307   06/05 - Jun  08, 2019    200       19.97      1       1048.74
# 87412               13-Apr-19    400       44.53      1       1046.29
# ...                       ...    ...         ...    ...           ...
# 134697   04/21 - Apr 22, 2017    200       46.14     18       -244.87
# 16762                8-Apr-17    100       27.72     16       -480.86
# 738      06/22 - Jun 24, 2017    200     01:05.6      7       -537.70
# 72117           Jun 5-8, 2019    100       35.78     24       -670.76
# 105470          Jun 5-8, 2019    100       35.78     24       -670.76
#
# [187176 rows x 8 columns]

# %%
# read final dataframe for analysis and modeling to csv
df.to_csv('final_performances_for_modeling.csv', index=False)
